# %%
from tkinter import *
import import_ipynb
import Teacher
import Student
import PyPDF2
import tkinter as tk
import PIL
from PIL import ImageTk
from PIL import Image
import datetime


date = datetime.datetime.now().date()

image = Image.open('Unity Loss.gif')
# The (450, 350) is (height, width)
image = image.resize((125, 100), Image.ANTIALIAS)

image2 = Image.open('194936.png')
image2 = image2.resize((90, 90), Image.ANTIALIAS)

image3 = Image.open('13.png')
image3 = image3.resize((90, 90), Image.ANTIALIAS)

class Application(object):
    def __init__(self,master):
        self.master = master

        #Frames
        self.top=Frame(master,height=150,bg='white')
        self.top.pack(fill=X)
        self.bottom=Frame(master,height=500,bg='#57a0d3')
        self.bottom.pack(fill=X)

        #Heading, image and date
        self.top_image= ImageTk.PhotoImage(image)
        #image200x100 = self.top_image.resize((200, 100), Image.ANTIALIAS)
        #self.top_image1= self.top_image.resize((250, 250))
        self.top_image_lbl=tk.Label(self.top,image=self.top_image,bg='white')
        self.top_image_lbl.place(x=120,y=10)
        
        self.heading=Label(self.top,text='Unity Loss',font='arial 15 bold',
                           fg='black',bg='white')
        self.heading.place(x=330,y=60)
        

        #Button 1
        self.btn1Icon=ImageTk.PhotoImage(image3)
        self.personBtn=Button(self.bottom,text='    Student  ',font='arial 12 bold',bg='#57a0d3',height = 480, 
        width = 300 ,command=self.openMyPeople1)
        self.personBtn.config(image=self.btn1Icon,compound=LEFT)
        self.personBtn.place(x=0, y=10)
        
        
        #Button 2
        self.btn2Icon=ImageTk.PhotoImage(image2)
        self.personBtn2=Button(self.bottom,text='    Teacher  ',font='arial 12 bold',bg='#57a0d3',height = 480, 
        width = 300,command=self.openMyPeople)
        self.personBtn2.config(image=self.btn2Icon,compound=LEFT)
        self.personBtn2.place(x=340, y=10)

    def openMyPeople(self):
        people=Teacher.MyPeople()
    def openMyPeople1(self):
        people1=Student.MyPeople()


   

def main():
    root = Tk()
    app = Application(root)
    root.title("Unity Loss")
    root.geometry("650x650+500+100")
    root.resizable(False,False)
    root.mainloop()
if __name__ == '__main__':
    main()
# Out:
# importing Jupyter notebook from Teacher.ipynb
# importing Jupyter notebook from Teacher_Interface.ipynb
# importing Jupyter notebook from Add_question.ipynb
# importing Jupyter notebook from Test.ipynb
# importing Jupyter notebook from Add_Answer.ipynb
# importing Jupyter notebook from Check_Paper.ipynb
# WARNING:tensorflow:From C:\Users\Raza Jutt\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# importing Jupyter notebook from Student.ipynb
# admin
# Printing id
# 1
# DONE
# ...
